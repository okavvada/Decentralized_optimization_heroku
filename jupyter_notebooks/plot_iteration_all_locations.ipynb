# %%
from __future__ import division
import csv
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import pylab as pl
get_ipython().magic(u'matplotlib inline')

# %%
data_financial = pd.read_csv('../iteration_results_financial.csv', header=None, skiprows = 1)
data_sunset = pd.read_csv('../iteration_results_sunset.csv', header=None, skiprows = 1)
data_twin = pd.read_csv('../iteration_results_twin.csv', header=None, skiprows = 1)
data_richmond = pd.read_csv('../iteration_results_richmond.csv', header=None, skiprows = 1)

# %%
cols = ['index', 'index_2','res_people', 'commercial_people', 'metric', 'in_build_pump', 'treat', 'treat_emb', 'piping']
data_financial.columns = cols
data_sunset.columns = cols
data_twin.columns = cols
data_richmond.columns = cols
data_financial['total_people'] = data_financial['res_people'] + data_financial['commercial_people'] 
data_sunset['total_people'] = data_sunset['res_people'] + data_sunset['commercial_people'] 
data_twin['total_people'] = data_twin['res_people'] + data_twin['commercial_people'] 
data_richmond['total_people'] = data_richmond['res_people'] + data_richmond['commercial_people'] 
data_financial['people_sum'] = data_financial.total_people.cumsum()
data_sunset['people_sum'] = data_sunset.total_people.cumsum()
data_twin['people_sum'] = data_twin.total_people.cumsum()
data_richmond['people_sum'] = data_richmond.total_people.cumsum()

# %%
data_financial.loc[:,['metric','in_build_pump', 'treat', 'treat_emb', 'piping']] /= 3.6 
data_richmond.loc[:,['metric','in_build_pump', 'treat', 'treat_emb', 'piping']] /= 3.6 
data_sunset.loc[:,['metric','in_build_pump', 'treat', 'treat_emb', 'piping']] /= 3.6 
data_twin.loc[:,['metric','in_build_pump', 'treat', 'treat_emb', 'piping']] /= 3.6

# %%
#data_financial = data_financial[3:]
plt.scatter(data_financial['people_sum'], data_financial['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('Energy ($kWh/m^3$)',fontsize =16)
plt.ylim(1.6,3.3)
plt.xlim(0,10000)
plt.xticks(fontsize =16)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
data_plot = data_financial[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_plot.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_plot.plot(kind='bar', stacked = True, colormap='PRGn', legend=False)
plt.xticks(np.arange(len(data_plot)), map(int, data_financial['people_sum']))
plt.ylabel('Energy ($kWh/m^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

# %%
plt.scatter(data_sunset['people_sum'], data_sunset['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('Energy ($kWh/m^3$)',fontsize =16)
#plt.ylim(11,24)
plt.xlim(-30,800)
plt.xticks(fontsize =16)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
data_plot = data_sunset[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_plot.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_plot.plot(kind='bar', stacked = True, colormap='PRGn', legend=False)
plt.xticks(np.arange(len(data_plot)), map(int, data_sunset['people_sum']))
plt.ylabel('Energy ($kWh/m^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

# %%
plt.scatter(data_richmond['people_sum'], data_richmond['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('Energy ($kWh/m^3$)',fontsize =16)
#plt.ylim(8,24)
plt.xlim(-30,1400)
plt.xticks(fontsize =16)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
data_plot = data_richmond[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_plot.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_plot.plot(kind='bar', stacked = True, colormap='PRGn', legend=False)
plt.xticks(np.arange(len(data_plot)), map(int, data_richmond['people_sum']))
plt.ylabel('Energy ($kWh/m^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

# %%
plt.scatter(data_twin['people_sum'], data_twin['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('Energy ($kWh/m^3$)',fontsize =16)
#plt.ylim(16,50)
plt.xlim(-10,160)
plt.xticks(fontsize =16)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
data_plot = data_twin[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_plot.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_plot.plot(kind='bar', stacked = True, colormap='PRGn', legend=False)
plt.xticks(np.arange(len(data_plot)), map(int, data_twin['people_sum']))
plt.ylabel('Energy ($kWh/m^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

# %%
thres = 1.1
data = data_richmond

# %%
metric_low = data['metric'].min()
metric_threshold = metric_low*thres
min_people = data.ix[(data['metric']-metric_threshold).abs().argsort()[:1]]['people_sum'].values[0]
max_threshold = (data['people_sum'].max() - min_people)/data['people_sum'].max()

# %%
max_threshold
# Out:
# 0.45477909720616749

# %%
min_people
# Out:
# 701.94383139600006

# %%
data
# Out:
#     index  index_2  res_people  commercial_people    metric  in_build_pump  \
# 0       0        0   29.493717                  2  6.271360       0.219949
# 1       1        1    7.406911                  0  6.085483       0.192357
# 2       2        2    5.896876                  0  5.935785       0.175138
# 3       3        3   14.194418                  0  5.588510       0.142606
# 4       4        4   13.058910                  0  5.281613       0.126478
# 5       5        6   19.381540                  0  4.959936       0.112455
# 6       6        8   27.133457                  0  4.630262       0.106321
# 7       7       10   40.509248                  0  4.297994       0.093777
# 8       8       13  126.284886                  0  3.647451       0.100174
# 9       9       16   23.577989                  0  3.591143       0.104583
# 10     10       20   53.232208                  0  3.510008       0.125286
# ...

# %%
#financial
max_threshold
# Out:
# 0.69695987186355146

# %%
#sunset
max_threshold
# Out:
# 0.59998939770852833

# %%
#twin
max_threshold
# Out:
# 0.47002615538874343

# %%
#richmond
max_threshold
# Out:
# 0.61234672978140814

# %%
sunset_final = pd.concat([data_sunset[0:1], data_sunset[-1:]])
financial_final = pd.concat([data_financial[0:1], data_financial[-1:]])
twin_final = pd.concat([data_twin[0:1], data_twin[-1:]])
richmond_final = pd.concat([data_richmond[1:2], data_richmond[-1:]])

# %%
sunset_final['area'] = 'C'
financial_final['area'] = 'B'
twin_final['area'] = 'D'
richmond_final['area'] = 'A'

# %%
data_all_sun = sunset_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_sun.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_all_fin = financial_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_fin.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_all_twin = twin_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_twin.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_all_rich = richmond_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_rich.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]

# %%
sunset_final.loc[sunset_final.index[0],'status'] = 'initial'
sunset_final.loc[sunset_final.index[-1],'status'] = 'optimal'
financial_final.loc[financial_final.index[0],'status'] = 'initial'
financial_final.loc[financial_final.index[-1],'status'] = 'optimal'
twin_final.loc[twin_final.index[0],'status'] = 'initial'
twin_final.loc[twin_final.index[-1],'status'] = 'optimal'
richmond_final.loc[richmond_final.index[0],'status'] = 'initial'
richmond_final.loc[richmond_final.index[-1],'status'] = 'optimal'

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot(1,4, 3)
data_all_sun.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, ax=ax)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.tick_params(right='off', left='off')
plt.xticks(np.arange(2), sunset_final['status'], fontsize = 16, rotation=90)
plt.ylim(0,14)
ax.annotate('C', xy=(0,14), fontsize = 18)
ax = fig.add_subplot(1,4, 2)
data_all_fin.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, sharey=True,ax=ax)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.tick_params(right='off', left='off')
plt.xticks(np.arange(2), financial_final['status'], fontsize = 16, rotation=90)
ax.annotate('B', xy=(0,14), fontsize = 18)
plt.ylim(0,14)
ax = fig.add_subplot(1,4, 4)
data_all_twin.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, ax=ax, sharey=True)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.tick_params(right='off', left='off')
plt.xticks(np.arange(2), twin_final['status'], fontsize = 16, rotation=90)
plt.ylim(0,14)
ax.annotate('D', xy=(0,14), fontsize = 18)
ax = fig.add_subplot(1,4, 1)
data_all_rich.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, ax=ax, sharey=True)
ax.spines["right"].set_visible(False)
ax.tick_params(right='off')
plt.xticks(np.arange(2), richmond_final['status'], fontsize = 16, rotation=90)
plt.ylabel('Energy ($kWh/m^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.ylim(0,14)
fig.tight_layout()
ax.annotate('A', xy=(0,14), fontsize = 18)
handles, labels = ax.get_legend_handles_labels()
plt.legend(reversed(handles), reversed(labels), loc='lower center', bbox_to_anchor=(6, 0.0),ncol=1, fancybox=True, shadow=True, fontsize=13)

# %% [markdown]
# # Cost

# %%
data_financial = pd.read_csv('../iteration_results_financial_cost.csv', header=None, skiprows = 1)
data_sunset = pd.read_csv('../iteration_results_sunset_cost.csv', header=None, skiprows = 1)
data_twin = pd.read_csv('../iteration_results_twin_cost.csv', header=None, skiprows = 1)
data_richmond = pd.read_csv('../iteration_results_richmond_cost.csv', header=None, skiprows = 1)

# %%
cols = ['index', 'index_2','res_people', 'commercial_people', 'metric', 'in_build_pump', 'treat', 'treat_emb', 'piping']
data_financial.columns = cols
data_sunset.columns = cols
data_twin.columns = cols
data_richmond.columns = cols
data_financial['total_people'] = data_financial['res_people'] + data_financial['commercial_people'] 
data_sunset['total_people'] = data_sunset['res_people'] + data_sunset['commercial_people'] 
data_twin['total_people'] = data_twin['res_people'] + data_twin['commercial_people'] 
data_richmond['total_people'] = data_richmond['res_people'] + data_richmond['commercial_people'] 
data_financial['people_sum'] = data_financial.total_people.cumsum()
data_sunset['people_sum'] = data_sunset.total_people.cumsum()
data_twin['people_sum'] = data_twin.total_people.cumsum()
data_richmond['people_sum'] = data_richmond.total_people.cumsum()

# %%
#data_financial = data_financial[3:]
plt.scatter(data_financial['people_sum'], data_financial['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('Cost ($USD/m^3$)',fontsize =16)
#plt.ylim(6,16)
#plt.xlim(-500,10000)
plt.xticks(fontsize =13)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
data_plot = data_financial[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_plot.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_plot.plot(kind='bar', stacked = True, colormap='PRGn', legend=False)
plt.xticks(np.arange(len(data_plot)), map(int, data_financial['people_sum']))
plt.ylabel('Cost ($USD/m^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

# %%
plt.scatter(data_twin['people_sum'], data_twin['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('Cost ($USD/m^3$)',fontsize =16)
#plt.ylim(6,16)
plt.xlim(0,120)
plt.xticks(fontsize =13)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
data_plot = data_twin[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_plot.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_plot.plot(kind='bar', stacked = True, colormap='PRGn', legend=False)
plt.xticks(np.arange(len(data_plot)), map(int, data_twin['people_sum']))
plt.ylabel('Cost ($USD/m^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

# %%
data_richmond = data_richmond[1:]
plt.scatter(data_richmond['people_sum'], data_richmond['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('Cost ($USD/m^3$)',fontsize =16)
#plt.ylim(6,16)
#plt.xlim(-500,10000)
plt.xticks(fontsize =13)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
data_plot = data_richmond[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_plot.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_plot.plot(kind='bar', stacked = True, colormap='PRGn', legend=False)
plt.xticks(np.arange(len(data_plot)), map(int, data_richmond['people_sum']))
plt.ylabel('Cost ($USD/m^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

# %%
plt.scatter(data_sunset['people_sum'], data_sunset['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('Cost ($USD/m^3$)',fontsize =16)
#plt.ylim(6,16)
#plt.xlim(-500,10000)
plt.xticks(fontsize =13)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
sunset_final = pd.concat([data_sunset[0:1], data_sunset[-1:]])
financial_final = pd.concat([data_financial[0:1], data_financial[-1:]])
twin_final = pd.concat([data_twin[1:2], data_twin[-1:]])
richmond_final = pd.concat([data_richmond[1:2], data_richmond[-1:]])
sunset_final['area'] = 'C'
financial_final['area'] = 'B'
twin_final['area'] = 'D'
richmond_final['area'] = 'A'
sunset_final.loc[sunset_final.index[0],'status'] = 'initial'
sunset_final.loc[sunset_final.index[-1],'status'] = 'optimal'
financial_final.loc[financial_final.index[0],'status'] = 'initial'
financial_final.loc[financial_final.index[-1],'status'] = 'optimal'
twin_final.loc[twin_final.index[0],'status'] = 'initial'
twin_final.loc[twin_final.index[-1],'status'] = 'optimal'
richmond_final.loc[richmond_final.index[0],'status'] = 'initial'
richmond_final.loc[richmond_final.index[-1],'status'] = 'optimal'

data_all_sun = sunset_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_sun.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_all_fin = financial_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_fin.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_all_twin = twin_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_twin.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_all_rich = richmond_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_rich.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot(1,4, 3)
data_all_sun.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, ax=ax)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.tick_params(right='off', left='off')
plt.xticks(np.arange(2), sunset_final['status'], fontsize = 16, rotation=90)
plt.ylim(0,14)
ax.annotate('C', xy=(0,14), fontsize = 18)
ax = fig.add_subplot(1,4, 2)
data_all_fin.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, sharey=True,ax=ax)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.tick_params(right='off', left='off')
plt.xticks(np.arange(2), financial_final['status'], fontsize = 16, rotation=90)
ax.annotate('B', xy=(0,14), fontsize = 18)
plt.ylim(0,14)
ax = fig.add_subplot(1,4, 4)
data_all_twin.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, ax=ax, sharey=True)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.tick_params(right='off', left='off')
plt.xticks(np.arange(2), twin_final['status'], fontsize = 16, rotation=90)
plt.ylim(0,14)
ax.annotate('D', xy=(0,14), fontsize = 18)
ax = fig.add_subplot(1,4, 1)
data_all_rich.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, ax=ax, sharey=True)
ax.spines["right"].set_visible(False)
ax.tick_params(right='off')
plt.xticks(np.arange(2), richmond_final['status'], fontsize = 16, rotation=90)
plt.ylabel('Cost ($USD/m^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.ylim(0,14)
fig.tight_layout()
ax.annotate('A', xy=(0,14), fontsize = 18)
handles, labels = ax.get_legend_handles_labels()
plt.legend(reversed(handles), reversed(labels), loc='lower center', bbox_to_anchor=(6, 0.0),ncol=1, fancybox=True, shadow=True, fontsize=13)

# %% [markdown]
# # GHG

# %%
data_financial = pd.read_csv('../iteration_results_financial_GHG_2.csv', header=None, skiprows = 1)
data_sunset = pd.read_csv('../iteration_results_sunset_GHG_2.csv', header=None, skiprows = 1)
data_twin = pd.read_csv('../iteration_results_twin_GHG_2.csv', header=None, skiprows = 1)
data_richmond = pd.read_csv('../iteration_results_richmond_GHG_2.csv', header=None, skiprows = 1)
cols = ['index', 'index_2','res_people', 'commercial_people', 'metric', 'in_build_pump', 'treat', 'treat_emb', 'piping']
data_financial.columns = cols
data_sunset.columns = cols
data_twin.columns = cols
data_richmond.columns = cols
data_financial['total_people'] = data_financial['res_people'] + data_financial['commercial_people'] 
data_sunset['total_people'] = data_sunset['res_people'] + data_sunset['commercial_people'] 
data_twin['total_people'] = data_twin['res_people'] + data_twin['commercial_people'] 
data_richmond['total_people'] = data_richmond['res_people'] + data_richmond['commercial_people'] 
data_financial['people_sum'] = data_financial.total_people.cumsum()
data_sunset['people_sum'] = data_sunset.total_people.cumsum()
data_twin['people_sum'] = data_twin.total_people.cumsum()
data_richmond['people_sum'] = data_richmond.total_people.cumsum()

# %%
data_financial = data_financial[0:]
plt.scatter(data_financial['people_sum'], data_financial['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('GHG (kgCO$_2(eq)$/m$^3$)',fontsize =16)
#plt.ylim(6,16)
#plt.xlim(-500,10000)
plt.xticks(fontsize =13)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
data_plot = data_financial[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_plot.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_plot.plot(kind='bar', stacked = True, colormap='PRGn', legend=False)
plt.xticks(np.arange(len(data_plot)), map(int, data_financial['people_sum']))
plt.ylabel('GHG (kgCO$_2(eq)$/m$^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

# %%
plt.scatter(data_sunset['people_sum'], data_sunset['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('GHG (kgCO$_2(eq)$/m$^3$)',fontsize =16)
#plt.ylim(6,16)
#plt.xlim(-500,10000)
plt.xticks(fontsize =13)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
data_plot = data_sunset[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_plot.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_plot.plot(kind='bar', stacked = True, colormap='PRGn', legend=False)
plt.xticks(np.arange(len(data_plot)), map(int, data_sunset['people_sum']))
plt.ylabel('GHG (kgCO$_2(eq)$/m$^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

# %%
plt.scatter(data_twin['people_sum'], data_twin['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('GHG (kgCO$_2(eq)$/m$^3$)',fontsize =16)
#plt.ylim(6,16)
#plt.xlim(-500,10000)
plt.xticks(fontsize =13)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
data_plot = data_twin[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_plot.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_plot.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.35)
plt.xticks(np.arange(len(data_plot)), map(int, data_twin['people_sum']))
plt.ylabel('GHG (kgCO$_2(eq)$/m$^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

# %%
plt.scatter(data_richmond['people_sum'], data_richmond['metric'], color = 'r', alpha=0.7, s=50)
plt.xlabel('Scale (# of people)',fontsize =16)
plt.ylabel('GHG (kgCO$_2(eq)$/m$^3$)',fontsize =16)
#plt.ylim(6,16)
#plt.xlim(-500,10000)
plt.xticks(fontsize =13)
plt.yticks(fontsize =16)
plt.grid(color='k', linestyle='--', linewidth=0.2, axis='both', alpha = 0.7)

# %%
data_plot = data_richmond[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_plot.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_plot.plot(kind='bar', stacked = True, colormap='PRGn', legend=False)
plt.xticks(np.arange(len(data_plot)), map(int, data_richmond['people_sum']))
plt.ylabel('GHG (kgCO$_2(eq)$/m$^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

# %%
sunset_final = pd.concat([data_sunset[0:1], data_sunset[-1:]])
financial_final = pd.concat([data_financial[0:1], data_financial[-1:]])
twin_final = pd.concat([data_twin[0:1], data_twin[-1:]])
richmond_final = pd.concat([data_richmond[0:1], data_richmond[-1:]])
sunset_final['area'] = 'C'
financial_final['area'] = 'B'
twin_final['area'] = 'D'
richmond_final['area'] = 'A'
sunset_final.loc[sunset_final.index[0],'status'] = 'initial'
sunset_final.loc[sunset_final.index[-1],'status'] = 'optimal'
financial_final.loc[financial_final.index[0],'status'] = 'initial'
financial_final.loc[financial_final.index[-1],'status'] = 'optimal'
twin_final.loc[twin_final.index[0],'status'] = 'initial'
twin_final.loc[twin_final.index[-1],'status'] = 'optimal'
richmond_final.loc[richmond_final.index[0],'status'] = 'initial'
richmond_final.loc[richmond_final.index[-1],'status'] = 'optimal'

data_all_sun = sunset_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_sun.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_all_fin = financial_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_fin.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_all_twin = twin_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_twin.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]
data_all_rich = richmond_final[['in_build_pump', 'treat', 'treat_emb', 'piping']]
data_all_rich.columns = [['pumping', 'treatment operation', 'treatment capital', 'piping']]

# %%
fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot(1,4, 3)
data_all_sun.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, ax=ax)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.tick_params(right='off', left='off')
plt.xticks(np.arange(2), sunset_final['status'], fontsize = 16, rotation=90)
plt.ylim(0,1.4)
ax.annotate('C', xy=(0,1.4), fontsize = 18)
ax = fig.add_subplot(1,4, 2)
data_all_fin.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, sharey=True,ax=ax)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.tick_params(right='off', left='off')
plt.xticks(np.arange(2), financial_final['status'], fontsize = 16, rotation=90)
ax.annotate('B', xy=(0,1.4), fontsize = 18)
plt.ylim(0,1.4)
ax = fig.add_subplot(1,4, 4)
data_all_twin.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, ax=ax, sharey=True)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.tick_params(right='off', left='off')
plt.xticks(np.arange(2), twin_final['status'], fontsize = 16, rotation=90)
plt.ylim(0,1.4)
ax.annotate('D', xy=(0,1.4), fontsize = 18)
ax = fig.add_subplot(1,4, 1)
data_all_rich.plot(kind='bar', stacked = True, colormap='PRGn', legend=False, width=0.9, ax=ax, sharey=True)
ax.spines["right"].set_visible(False)
ax.tick_params(right='off')
plt.xticks(np.arange(2), richmond_final['status'], fontsize = 16, rotation=90)
plt.ylabel('GHG (kgCO$_2(eq)$/m$^3$)',fontsize =14)
plt.yticks(fontsize =14)
plt.ylim(0,1.4)
fig.tight_layout()
ax.annotate('A', xy=(0,1.4), fontsize = 18)
handles, labels = ax.get_legend_handles_labels()
plt.legend(reversed(handles), reversed(labels), loc='lower center', bbox_to_anchor=(6, 0.0),ncol=1, fancybox=True, shadow=True, fontsize=13)

# %%
data_all_sun
# Out:
#     pumping  treatment operation  treatment capital    piping
# 0  0.005807             0.464535               0.06  0.071243
# 9  0.032014             0.201055               0.06  0.155911

# %%
data_all_sun
# Out:
#      pumping  treatment operation  treatment capital    piping
# 0   0.195809             5.729711                0.3  0.285908
# 30  0.297658             2.254489                0.3  0.537273

# %%
data_all_fin
# Out:
#      pumping  treatment operation  treatment capital    piping
# 2   0.209349             3.516981                0.3  0.243640
# 47  0.274185             0.987997                0.3  0.137203

# %%
data_all_twin
# Out:
#      pumping  treatment operation  treatment capital    piping
# 0   0.007081            12.599073                0.3  0.332797
# 39  0.211846             3.532189                0.3  1.057876

# %%
data_all_rich
# Out:
#      pumping  treatment operation  treatment capital    piping
# 1   0.192357             5.243268                0.3  0.349858
# 33  0.178597             1.852317                0.3  0.435492
